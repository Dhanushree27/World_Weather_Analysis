# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
latitude=np.random.uniform(-90.000,90.000,size=1500)
longitude=np.random.uniform(-180.000,180.000,size=1500)
lat_lngs=zip(latitude,longitude)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy module
from citipy import citipy

# %%
# Identifying and adding cities to a list
cities=[]
# Looping through all coordinates
for coord in coordinates:
    # Identifying city
    city=citipy.nearest_city(coord[0],coord[1]).city_name
    # Check if city already exists in list
    if city not in cities:
        cities.append(city)
# Check to verify whether count is sufficient
len(cities)
# Out:
# 640

# %%
# Importing dependencies
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# URL to import weather data
url="http://api.openweathermap.org/data/2.5/weather?units=imperial&appid="+weather_api_key
# Empty list to store dictionary data for each city
city_data=[]

# %%
# Print the beginning of the logging
print("Beginning data retrieval     ")
print("-----------------------------")

# Create counters
record_count=1
set_count=1

# Retrieve city data
for i,city in enumerate(cities):
    # Group cities in sets of 50 to prevent time-out
    if (i>=50 and i%50==0):
        time.sleep(60)
        # Increasing set count after each 50
        set_count=set_count+1
        record_count=1
    # Creating URL for each city
    city_url=url+"&q="+city.replace(" ","+")
       
    try:
         # Retrieving data for each city
        city_weather = requests.get(city_url).json()    
        # Reading json data and adding to the list as dictionaries
        city_data.append({"City":city,
                         "Country":city_weather["sys"]["country"],
                         "Date":datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S'),
                         "Lat":city_weather["coord"]["lat"],
                         "Lng":city_weather["coord"]["lon"],
                         "Max Temp":city_weather["main"]["temp_max"],
                         "Humidity":city_weather["main"]["humidity"],
                         "Cloudiness":city_weather["clouds"]["all"],
                         "Wind Speed":city_weather["wind"]["speed"]})
    except:
        print(f"{city} not found")
        pass
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Increasing the record count
    record_count=record_count+1
      
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning data retrieval
# -----------------------------
# Processing Record 1 of Set 1 | esmeralda
# Processing Record 2 of Set 1 | east london
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | tekirdag
# Processing Record 6 of Set 1 | new norfolk
# tsihombe not found
# Processing Record 7 of Set 1 | tsihombe
# Processing Record 8 of Set 1 | alihe
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | luderitz
# Processing Record 11 of Set 1 | pozo colorado
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | provideniya
# Processing Record 16 of Set 1 | airai
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | sheridan
# sentyabrskiy not found
# Processing Record 22 of Set 1 | sentyabrskiy
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | lagoa
# Processing Record 27 of Set 1 | sur
# Processing Record 28 of Set 1 | vila do maio
# Processing Record 29 of Set 1 | vestmannaeyjar
# barentsburg not found
# Processing Record 30 of Set 1 | barentsburg
# Processing Record 31 of Set 1 | bethel
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | nanortalik
# Processing Record 34 of Set 1 | arraial do cabo
# nizhneyansk not found
# Processing Record 35 of Set 1 | nizhneyansk
# Processing Record 36 of Set 1 | mitu
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | haines junction
# Processing Record 40 of Set 1 | bambous virieux
# Processing Record 41 of Set 1 | lebedinyy
# Processing Record 42 of Set 1 | hasaki
# Processing Record 43 of Set 1 | villazon
# Processing Record 44 of Set 1 | matara
# Processing Record 45 of Set 1 | fort frances
# Processing Record 46 of Set 1 | ilulissat
# Processing Record 47 of Set 1 | nanakuli
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | washington
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | cachoeiras de macacu
# Processing Record 2 of Set 2 | aksarka
# Processing Record 3 of Set 2 | rio esteban
# Processing Record 4 of Set 2 | mao
# Processing Record 5 of Set 2 | upernavik
# Processing Record 6 of Set 2 | shingu
# Processing Record 7 of Set 2 | isangel
# Processing Record 8 of Set 2 | ponta do sol
# Processing Record 9 of Set 2 | salalah
# Processing Record 10 of Set 2 | ancud
# Processing Record 11 of Set 2 | lourdes
# Processing Record 12 of Set 2 | torbay
# Processing Record 13 of Set 2 | sochi
# Processing Record 14 of Set 2 | tadine
# Processing Record 15 of Set 2 | geraldton
# agva not found
# Processing Record 16 of Set 2 | agva
# Processing Record 17 of Set 2 | george town
# Processing Record 18 of Set 2 | coquimbo
# Processing Record 19 of Set 2 | colorines
# Processing Record 20 of Set 2 | springbok
# Processing Record 21 of Set 2 | ucluelet
# toftir not found
# Processing Record 22 of Set 2 | toftir
# Processing Record 23 of Set 2 | ushuaia
# saleaula not found
# Processing Record 24 of Set 2 | saleaula
# Processing Record 25 of Set 2 | busselton
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | saint-francois
# Processing Record 28 of Set 2 | yatou
# Processing Record 29 of Set 2 | port macquarie
# Processing Record 30 of Set 2 | tshikapa
# Processing Record 31 of Set 2 | camacha
# Processing Record 32 of Set 2 | rantauprapat
# Processing Record 33 of Set 2 | timmins
# Processing Record 34 of Set 2 | honggang
# Processing Record 35 of Set 2 | mataura
# belushya guba not found
# Processing Record 36 of Set 2 | belushya guba
# Processing Record 37 of Set 2 | hambantota
# Processing Record 38 of Set 2 | lishui
# Processing Record 39 of Set 2 | shimoda
# Processing Record 40 of Set 2 | emerald
# Processing Record 41 of Set 2 | creel
# Processing Record 42 of Set 2 | saskylakh
# Processing Record 43 of Set 2 | tasiilaq
# Processing Record 44 of Set 2 | nizwa
# Processing Record 45 of Set 2 | shirokiy
# pilao arcado not found
# Processing Record 46 of Set 2 | pilao arcado
# taolanaro not found
# Processing Record 47 of Set 2 | taolanaro
# Processing Record 48 of Set 2 | narsaq
# Processing Record 49 of Set 2 | cockburn town
# Processing Record 50 of Set 2 | yar-sale
# Processing Record 1 of Set 3 | namibe
# Processing Record 2 of Set 3 | victoria
# Processing Record 3 of Set 3 | aki
# Processing Record 4 of Set 3 | vila velha
# Processing Record 5 of Set 3 | labuhan
# Processing Record 6 of Set 3 | faanui
# Processing Record 7 of Set 3 | trat
# Processing Record 8 of Set 3 | katav-ivanovsk
# Processing Record 9 of Set 3 | tuktoyaktuk
# Processing Record 10 of Set 3 | kawalu
# Processing Record 11 of Set 3 | kaitangata
# artyk not found
# Processing Record 12 of Set 3 | artyk
# Processing Record 13 of Set 3 | dunedin
# Processing Record 14 of Set 3 | vao
# Processing Record 15 of Set 3 | chokurdakh
# Processing Record 16 of Set 3 | san pedro de macoris
# Processing Record 17 of Set 3 | kapoeta
# Processing Record 18 of Set 3 | nikolskoye
# Processing Record 19 of Set 3 | colesberg
# Processing Record 20 of Set 3 | barrow
# Processing Record 21 of Set 3 | avarua
# Processing Record 22 of Set 3 | sagua la grande
# vaitupu not found
# Processing Record 23 of Set 3 | vaitupu
# Processing Record 24 of Set 3 | konstantinovka
# Processing Record 25 of Set 3 | saldanha
# Processing Record 26 of Set 3 | mackenzie
# Processing Record 27 of Set 3 | bowen
# Processing Record 28 of Set 3 | ponta delgada
# Processing Record 29 of Set 3 | poum
# Processing Record 30 of Set 3 | grand gaube
# Processing Record 31 of Set 3 | cape town
# Processing Record 32 of Set 3 | manama
# illoqqortoormiut not found
# Processing Record 33 of Set 3 | illoqqortoormiut
# Processing Record 34 of Set 3 | pacific grove
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | port hardy
# Processing Record 37 of Set 3 | kudahuvadhoo
# Processing Record 38 of Set 3 | khatanga
# Processing Record 39 of Set 3 | puerto ayora
# Processing Record 40 of Set 3 | scarborough
# Processing Record 41 of Set 3 | tutoia
# Processing Record 42 of Set 3 | jumla
# Processing Record 43 of Set 3 | inhambane
# grand river south east not found
# Processing Record 44 of Set 3 | grand river south east
# Processing Record 45 of Set 3 | olinda
# Processing Record 46 of Set 3 | waingapu
# Processing Record 47 of Set 3 | san nicolas
# utiroa not found
# Processing Record 48 of Set 3 | utiroa
# mocambique not found
# Processing Record 49 of Set 3 | mocambique
# Processing Record 50 of Set 3 | matagami
# Processing Record 1 of Set 4 | nuuk
# Processing Record 2 of Set 4 | konevo
# Processing Record 3 of Set 4 | havre-saint-pierre
# Processing Record 4 of Set 4 | kutum
# Processing Record 5 of Set 4 | port elizabeth
# Processing Record 6 of Set 4 | pandan
# Processing Record 7 of Set 4 | mareeba
# Processing Record 8 of Set 4 | dombarovskiy
# Processing Record 9 of Set 4 | ludvika
# Processing Record 10 of Set 4 | matamoros
# Processing Record 11 of Set 4 | wainwright
# palabuhanratu not found
# Processing Record 12 of Set 4 | palabuhanratu
# Processing Record 13 of Set 4 | bay city
# karamea not found
# Processing Record 14 of Set 4 | karamea
# Processing Record 15 of Set 4 | saint-philippe
# Processing Record 16 of Set 4 | husavik
# Processing Record 17 of Set 4 | maputo
# Processing Record 18 of Set 4 | waipawa
# Processing Record 19 of Set 4 | ndele
# Processing Record 20 of Set 4 | san quintin
# Processing Record 21 of Set 4 | mizan teferi
# Processing Record 22 of Set 4 | ixtapa
# Processing Record 23 of Set 4 | clyde river
# Processing Record 24 of Set 4 | boali
# Processing Record 25 of Set 4 | college
# Processing Record 26 of Set 4 | bud
# Processing Record 27 of Set 4 | comodoro rivadavia
# Processing Record 28 of Set 4 | port blair
# Processing Record 29 of Set 4 | galesong
# Processing Record 30 of Set 4 | baie-comeau
# Processing Record 31 of Set 4 | longyearbyen
# Processing Record 32 of Set 4 | carnarvon
# Processing Record 33 of Set 4 | dakar
# Processing Record 34 of Set 4 | sitka
# Processing Record 35 of Set 4 | maceio
# Processing Record 36 of Set 4 | baherden
# Processing Record 37 of Set 4 | urengoy
# sorvag not found
# Processing Record 38 of Set 4 | sorvag
# Processing Record 39 of Set 4 | north bend
# bajo baudo not found
# Processing Record 40 of Set 4 | bajo baudo
# Processing Record 41 of Set 4 | hadejia
# Processing Record 42 of Set 4 | kruisfontein
# Processing Record 43 of Set 4 | casablanca
# grand centre not found
# Processing Record 44 of Set 4 | grand centre
# Processing Record 45 of Set 4 | prince rupert
# Processing Record 46 of Set 4 | mporokoso
# Processing Record 47 of Set 4 | golden
# Processing Record 48 of Set 4 | gazanjyk
# Processing Record 49 of Set 4 | ahipara
# Processing Record 50 of Set 4 | cabo rojo
# Processing Record 1 of Set 5 | mahebourg
# Processing Record 2 of Set 5 | stephenville
# Processing Record 3 of Set 5 | yumen
# Processing Record 4 of Set 5 | sibolga
# Processing Record 5 of Set 5 | bengkulu
# Processing Record 6 of Set 5 | lebu
# mys shmidta not found
# Processing Record 7 of Set 5 | mys shmidta
# Processing Record 8 of Set 5 | kearney
# Processing Record 9 of Set 5 | butterworth
# Processing Record 10 of Set 5 | alekseyevsk
# kamenskoye not found
# Processing Record 11 of Set 5 | kamenskoye
# Processing Record 12 of Set 5 | dogondoutchi
# Processing Record 13 of Set 5 | boa vista
# Processing Record 14 of Set 5 | vaini
# Processing Record 15 of Set 5 | palasa
# Processing Record 16 of Set 5 | valley city
# bokspits not found
# Processing Record 17 of Set 5 | bokspits
# tubruq not found
# Processing Record 18 of Set 5 | tubruq
# Processing Record 19 of Set 5 | tuatapere
# Processing Record 20 of Set 5 | orumiyeh
# Processing Record 21 of Set 5 | bathsheba
# Processing Record 22 of Set 5 | shenzhen
# Processing Record 23 of Set 5 | kabanjahe
# Processing Record 24 of Set 5 | bambari
# Processing Record 25 of Set 5 | rena
# Processing Record 26 of Set 5 | olafsvik
# Processing Record 27 of Set 5 | atakpame
# Processing Record 28 of Set 5 | bow island
# Processing Record 29 of Set 5 | vuktyl
# acuna not found
# Processing Record 30 of Set 5 | acuna
# Processing Record 31 of Set 5 | fussa
# Processing Record 32 of Set 5 | hokitika
# Processing Record 33 of Set 5 | luanda
# Processing Record 34 of Set 5 | saint anthony
# Processing Record 35 of Set 5 | constitucion
# Processing Record 36 of Set 5 | swan river
# Processing Record 37 of Set 5 | arica
# Processing Record 38 of Set 5 | kuching
# Processing Record 39 of Set 5 | port lincoln
# Processing Record 40 of Set 5 | erdemli
# Processing Record 41 of Set 5 | piranhas
# Processing Record 42 of Set 5 | dikson
# Processing Record 43 of Set 5 | carmelo
# hvammstangi not found
# Processing Record 44 of Set 5 | hvammstangi
# gorno-chuyskiy not found
# Processing Record 45 of Set 5 | gorno-chuyskiy
# Processing Record 46 of Set 5 | cidreira
# Processing Record 47 of Set 5 | thinadhoo
# Processing Record 48 of Set 5 | port hedland
# Processing Record 49 of Set 5 | korostyshiv
# Processing Record 50 of Set 5 | huadian
# Processing Record 1 of Set 6 | mafinga
# Processing Record 2 of Set 6 | naron
# Processing Record 3 of Set 6 | tecoanapa
# Processing Record 4 of Set 6 | zeya
# Processing Record 5 of Set 6 | pascagoula
# Processing Record 6 of Set 6 | quelimane
# Processing Record 7 of Set 6 | qaanaaq
# formoso do araguaia not found
# Processing Record 8 of Set 6 | formoso do araguaia
# Processing Record 9 of Set 6 | durban
# Processing Record 10 of Set 6 | sao paulo de olivenca
# Processing Record 11 of Set 6 | arapongas
# Processing Record 12 of Set 6 | tiksi
# Processing Record 13 of Set 6 | manta
# Processing Record 14 of Set 6 | buala
# marcona not found
# Processing Record 15 of Set 6 | marcona
# Processing Record 16 of Set 6 | ostrovnoy
# Processing Record 17 of Set 6 | russell
# Processing Record 18 of Set 6 | plettenberg bay
# tabiauea not found
# Processing Record 19 of Set 6 | tabiauea
# Processing Record 20 of Set 6 | nioki
# Processing Record 21 of Set 6 | codrington
# Processing Record 22 of Set 6 | rio gallegos
# Processing Record 23 of Set 6 | ipixuna
# Processing Record 24 of Set 6 | asau
# Processing Record 25 of Set 6 | yafran
# Processing Record 26 of Set 6 | edelira
# Processing Record 27 of Set 6 | vangaindrano
# Processing Record 28 of Set 6 | te anau
# Processing Record 29 of Set 6 | harper
# Processing Record 30 of Set 6 | ola
# Processing Record 31 of Set 6 | sao joao da barra
# Processing Record 32 of Set 6 | kodinsk
# Processing Record 33 of Set 6 | sorland
# Processing Record 34 of Set 6 | rawson
# lolua not found
# Processing Record 35 of Set 6 | lolua
# Processing Record 36 of Set 6 | santiago del estero
# Processing Record 37 of Set 6 | tucuma
# Processing Record 38 of Set 6 | sao filipe
# Processing Record 39 of Set 6 | srednekolymsk
# Processing Record 40 of Set 6 | forssa
# Processing Record 41 of Set 6 | hasanabad
# Processing Record 42 of Set 6 | minab
# Processing Record 43 of Set 6 | mathbaria
# Processing Record 44 of Set 6 | westport
# Processing Record 45 of Set 6 | namatanai
# Processing Record 46 of Set 6 | tezu
# Processing Record 47 of Set 6 | buchanan
# Processing Record 48 of Set 6 | flinders
# Processing Record 49 of Set 6 | tlacotepec
# Processing Record 50 of Set 6 | tateyama
# Processing Record 1 of Set 7 | port moresby
# Processing Record 2 of Set 7 | bafata
# Processing Record 3 of Set 7 | strezhevoy
# Processing Record 4 of Set 7 | vardo
# Processing Record 5 of Set 7 | pisco
# Processing Record 6 of Set 7 | grindavik
# Processing Record 7 of Set 7 | gizo
# Processing Record 8 of Set 7 | chara
# Processing Record 9 of Set 7 | komsomolskiy
# Processing Record 10 of Set 7 | oussouye
# Processing Record 11 of Set 7 | humberto de campos
# Processing Record 12 of Set 7 | alexandria
# Processing Record 13 of Set 7 | baculin
# Processing Record 14 of Set 7 | chuy
# Processing Record 15 of Set 7 | avera
# Processing Record 16 of Set 7 | hay river
# Processing Record 17 of Set 7 | maine-soroa
# Processing Record 18 of Set 7 | thompson
# Processing Record 19 of Set 7 | tocopilla
# Processing Record 20 of Set 7 | manicore
# Processing Record 21 of Set 7 | parrita
# Processing Record 22 of Set 7 | lorengau
# Processing Record 23 of Set 7 | castro
# Processing Record 24 of Set 7 | port hawkesbury
# Processing Record 25 of Set 7 | gat
# Processing Record 26 of Set 7 | golovchino
# Processing Record 27 of Set 7 | lecco
# Processing Record 28 of Set 7 | noshiro
# Processing Record 29 of Set 7 | hermsdorf
# Processing Record 30 of Set 7 | kalevala
# Processing Record 31 of Set 7 | catemaco
# Processing Record 32 of Set 7 | fortuna
# Processing Record 33 of Set 7 | mehamn
# Processing Record 34 of Set 7 | cabo san lucas
# Processing Record 35 of Set 7 | kahului
# Processing Record 36 of Set 7 | yarada
# Processing Record 37 of Set 7 | palaia fokaia
# Processing Record 38 of Set 7 | sakakah
# Processing Record 39 of Set 7 | ngorongoro
# Processing Record 40 of Set 7 | yerbogachen
# Processing Record 41 of Set 7 | egvekinot
# Processing Record 42 of Set 7 | nara
# Processing Record 43 of Set 7 | deer lake
# Processing Record 44 of Set 7 | pombia
# Processing Record 45 of Set 7 | nome
# Processing Record 46 of Set 7 | sao jose da coroa grande
# Processing Record 47 of Set 7 | levelland
# Processing Record 48 of Set 7 | salta
# Processing Record 49 of Set 7 | naze
# Processing Record 50 of Set 7 | acajutla
# Processing Record 1 of Set 8 | atasu
# Processing Record 2 of Set 8 | vilyuysk
# Processing Record 3 of Set 8 | bandarbeyla
# Processing Record 4 of Set 8 | tortoli
# Processing Record 5 of Set 8 | klaksvik
# Processing Record 6 of Set 8 | ulladulla
# Processing Record 7 of Set 8 | angoche
# attawapiskat not found
# Processing Record 8 of Set 8 | attawapiskat
# Processing Record 9 of Set 8 | ribeira grande
# Processing Record 10 of Set 8 | lingao
# Processing Record 11 of Set 8 | zelenogradsk
# Processing Record 12 of Set 8 | san cristobal
# Processing Record 13 of Set 8 | wyndham
# Processing Record 14 of Set 8 | bayir
# Processing Record 15 of Set 8 | anloga
# Processing Record 16 of Set 8 | kikwit
# Processing Record 17 of Set 8 | adrar
# Processing Record 18 of Set 8 | shelburne
# Processing Record 19 of Set 8 | awjilah
# Processing Record 20 of Set 8 | kavieng
# Processing Record 21 of Set 8 | goundam
# Processing Record 22 of Set 8 | albanel
# Processing Record 23 of Set 8 | mago
# Processing Record 24 of Set 8 | sovetskiy
# Processing Record 25 of Set 8 | aden
# viligili not found
# Processing Record 26 of Set 8 | viligili
# Processing Record 27 of Set 8 | goderich
# Processing Record 28 of Set 8 | guane
# Processing Record 29 of Set 8 | mount gambier
# Processing Record 30 of Set 8 | batticaloa
# Processing Record 31 of Set 8 | astana
# tumannyy not found
# Processing Record 32 of Set 8 | tumannyy
# Processing Record 33 of Set 8 | newala
# Processing Record 34 of Set 8 | mumbwa
# Processing Record 35 of Set 8 | lasa
# Processing Record 36 of Set 8 | mitsamiouli
# Processing Record 37 of Set 8 | durango
# Processing Record 38 of Set 8 | riyadh
# Processing Record 39 of Set 8 | naryan-mar
# Processing Record 40 of Set 8 | katsuura
# Processing Record 41 of Set 8 | masuri
# Processing Record 42 of Set 8 | rocha
# Processing Record 43 of Set 8 | roma
# Processing Record 44 of Set 8 | norman wells
# Processing Record 45 of Set 8 | hamilton
# Processing Record 46 of Set 8 | khandyga
# Processing Record 47 of Set 8 | kasongo-lunda
# Processing Record 48 of Set 8 | paamiut
# Processing Record 49 of Set 8 | pemberton
# Processing Record 50 of Set 8 | port-de-bouc
# Processing Record 1 of Set 9 | wageningen
# Processing Record 2 of Set 9 | soyo
# Processing Record 3 of Set 9 | mogadishu
# Processing Record 4 of Set 9 | mocuba
# Processing Record 5 of Set 9 | vryburg
# zhanatas not found
# Processing Record 6 of Set 9 | zhanatas
# Processing Record 7 of Set 9 | camana
# Processing Record 8 of Set 9 | laela
# Processing Record 9 of Set 9 | igrim
# Processing Record 10 of Set 9 | jibuti
# Processing Record 11 of Set 9 | anito
# Processing Record 12 of Set 9 | puerto cabezas
# bolungarvik not found
# Processing Record 13 of Set 9 | bolungarvik
# Processing Record 14 of Set 9 | yelizovo
# Processing Record 15 of Set 9 | sabang
# Processing Record 16 of Set 9 | dhidhdhoo
# rolim de moura not found
# Processing Record 17 of Set 9 | rolim de moura
# umzimvubu not found
# Processing Record 18 of Set 9 | umzimvubu
# Processing Record 19 of Set 9 | aksu
# Processing Record 20 of Set 9 | umm kaddadah
# Processing Record 21 of Set 9 | great yarmouth
# Processing Record 22 of Set 9 | balezino
# Processing Record 23 of Set 9 | bystrice nad pernstejnem
# Processing Record 24 of Set 9 | sinop
# Processing Record 25 of Set 9 | belyy yar
# Processing Record 26 of Set 9 | udankudi
# Processing Record 27 of Set 9 | okhotsk
# Processing Record 28 of Set 9 | vestmanna
# Processing Record 29 of Set 9 | pedro ii
# Processing Record 30 of Set 9 | zarichne
# Processing Record 31 of Set 9 | benjamin constant
# Processing Record 32 of Set 9 | iqaluit
# Processing Record 33 of Set 9 | rayong
# Processing Record 34 of Set 9 | atbasar
# Processing Record 35 of Set 9 | newport
# Processing Record 36 of Set 9 | baruun-urt
# Processing Record 37 of Set 9 | adeje
# kazalinsk not found
# Processing Record 38 of Set 9 | kazalinsk
# Processing Record 39 of Set 9 | camargo
# Processing Record 40 of Set 9 | krasnoselkup
# yirol not found
# Processing Record 41 of Set 9 | yirol
# Processing Record 42 of Set 9 | oranjestad
# Processing Record 43 of Set 9 | abu kamal
# Processing Record 44 of Set 9 | berbera
# Processing Record 45 of Set 9 | atambua
# Processing Record 46 of Set 9 | portland
# Processing Record 47 of Set 9 | lannion
# Processing Record 48 of Set 9 | saint-augustin
# Processing Record 49 of Set 9 | santa maria
# Processing Record 50 of Set 9 | gamba
# Processing Record 1 of Set 10 | bako
# Processing Record 2 of Set 10 | talnakh
# scottsburgh not found
# Processing Record 3 of Set 10 | scottsburgh
# Processing Record 4 of Set 10 | yantal
# Processing Record 5 of Set 10 | mahibadhoo
# Processing Record 6 of Set 10 | xining
# Processing Record 7 of Set 10 | kanigoro
# Processing Record 8 of Set 10 | llaillay
# amderma not found
# Processing Record 9 of Set 10 | amderma
# bur gabo not found
# Processing Record 10 of Set 10 | bur gabo
# Processing Record 11 of Set 10 | cabedelo
# Processing Record 12 of Set 10 | graaff-reinet
# Processing Record 13 of Set 10 | los llanos de aridane
# Processing Record 14 of Set 10 | tiznit
# Processing Record 15 of Set 10 | ust-maya
# Processing Record 16 of Set 10 | walvis bay
# Processing Record 17 of Set 10 | abha
# dzhusaly not found
# Processing Record 18 of Set 10 | dzhusaly
# Processing Record 19 of Set 10 | cuamba
# nguiu not found
# Processing Record 20 of Set 10 | nguiu
# Processing Record 21 of Set 10 | muli
# Processing Record 22 of Set 10 | korla
# Processing Record 23 of Set 10 | roald
# Processing Record 24 of Set 10 | kamenka
# Processing Record 25 of Set 10 | high level
# Processing Record 26 of Set 10 | denpasar
# Processing Record 27 of Set 10 | abhayapuri
# Processing Record 28 of Set 10 | pudozh
# Processing Record 29 of Set 10 | pingzhuang
# Processing Record 30 of Set 10 | sydney
# Processing Record 31 of Set 10 | huarmey
# Processing Record 32 of Set 10 | nemuro
# Processing Record 33 of Set 10 | meulaboh
# Processing Record 34 of Set 10 | washougal
# Processing Record 35 of Set 10 | turukhansk
# Processing Record 36 of Set 10 | pailon
# Processing Record 37 of Set 10 | cayenne
# Processing Record 38 of Set 10 | kyaikto
# Processing Record 39 of Set 10 | ambon
# Processing Record 40 of Set 10 | takestan
# Processing Record 41 of Set 10 | maniwaki
# Processing Record 42 of Set 10 | oranjemund
# Processing Record 43 of Set 10 | amnat charoen
# Processing Record 44 of Set 10 | chulym
# Processing Record 45 of Set 10 | houston
# Processing Record 46 of Set 10 | nadvoitsy
# Processing Record 47 of Set 10 | san luis
# Processing Record 48 of Set 10 | honiara
# Processing Record 49 of Set 10 | oistins
# Processing Record 50 of Set 10 | muscat
# Processing Record 1 of Set 11 | zhezkazgan
# Processing Record 2 of Set 11 | moche
# Processing Record 3 of Set 11 | carutapera
# Processing Record 4 of Set 11 | broome
# kuche not found
# Processing Record 5 of Set 11 | kuche
# Processing Record 6 of Set 11 | fairbanks
# Processing Record 7 of Set 11 | la ciotat
# Processing Record 8 of Set 11 | pangkalanbuun
# Processing Record 9 of Set 11 | luganville
# Processing Record 10 of Set 11 | porto seguro
# Processing Record 11 of Set 11 | troitskoye
# Processing Record 12 of Set 11 | alugan
# Processing Record 13 of Set 11 | zhigansk
# Processing Record 14 of Set 11 | pangnirtung
# Processing Record 15 of Set 11 | alenquer
# Processing Record 16 of Set 11 | soma
# Processing Record 17 of Set 11 | beli manastir
# sahrak not found
# Processing Record 18 of Set 11 | sahrak
# Processing Record 19 of Set 11 | hare bay
# Processing Record 20 of Set 11 | morant bay
# bursol not found
# Processing Record 21 of Set 11 | bursol
# Processing Record 22 of Set 11 | neryungri
# Processing Record 23 of Set 11 | bambanglipuro
# Processing Record 24 of Set 11 | jacareacanga
# Processing Record 25 of Set 11 | chaman
# Processing Record 26 of Set 11 | muroto
# Processing Record 27 of Set 11 | yulara
# Processing Record 28 of Set 11 | toamasina
# santa eulalia del rio not found
# Processing Record 29 of Set 11 | santa eulalia del rio
# Processing Record 30 of Set 11 | seymchan
# Processing Record 31 of Set 11 | salinopolis
# Processing Record 32 of Set 11 | mount isa
# Processing Record 33 of Set 11 | manosque
# Processing Record 34 of Set 11 | puerto ayacucho
# Processing Record 35 of Set 11 | kaeo
# Processing Record 36 of Set 11 | lingyuan
# Processing Record 37 of Set 11 | ormara
# Processing Record 38 of Set 11 | sanchez
# Processing Record 39 of Set 11 | dali
# Processing Record 40 of Set 11 | kimbe
# Processing Record 41 of Set 11 | det udom
# Processing Record 42 of Set 11 | rock springs
# Processing Record 43 of Set 11 | caravelas
# Processing Record 44 of Set 11 | banda aceh
# Processing Record 45 of Set 11 | west wendover
# Processing Record 46 of Set 11 | lompoc
# Processing Record 47 of Set 11 | vila franca do campo
# Processing Record 48 of Set 11 | shakiso
# Processing Record 49 of Set 11 | charters towers
# Processing Record 50 of Set 11 | cururupu
# Processing Record 1 of Set 12 | caborca
# Processing Record 2 of Set 12 | solkan
# Processing Record 3 of Set 12 | teguise
# Processing Record 4 of Set 12 | nizhneudinsk
# Processing Record 5 of Set 12 | fukue
# Processing Record 6 of Set 12 | klyuchi
# Processing Record 7 of Set 12 | lincoln
# Processing Record 8 of Set 12 | jaciara
# Processing Record 9 of Set 12 | luba
# Processing Record 10 of Set 12 | ilhabela
# Processing Record 11 of Set 12 | limburg
# Processing Record 12 of Set 12 | nouadhibou
# Processing Record 13 of Set 12 | gornozavodsk
# Processing Record 14 of Set 12 | inirida
# Processing Record 15 of Set 12 | trujillo
# Processing Record 16 of Set 12 | charleville-mezieres
# karistos not found
# Processing Record 17 of Set 12 | karistos
# Processing Record 18 of Set 12 | necochea
# Processing Record 19 of Set 12 | sonqor
# Processing Record 20 of Set 12 | pechenga
# Processing Record 21 of Set 12 | khuzhir
# Processing Record 22 of Set 12 | noumea
# Processing Record 23 of Set 12 | hofn
# guajara-mirim not found
# Processing Record 24 of Set 12 | guajara-mirim
# Processing Record 25 of Set 12 | shache
# samusu not found
# Processing Record 26 of Set 12 | samusu
# balimo not found
# Processing Record 27 of Set 12 | balimo
# Processing Record 28 of Set 12 | katangli
# Processing Record 29 of Set 12 | northam
# Processing Record 30 of Set 12 | sao felix do xingu
# Processing Record 31 of Set 12 | taicheng
# Processing Record 32 of Set 12 | juneau
# almenevo not found
# Processing Record 33 of Set 12 | almenevo
# Processing Record 34 of Set 12 | shaikhpura
# Processing Record 35 of Set 12 | dryden
# Processing Record 36 of Set 12 | augusto correa
# Processing Record 37 of Set 12 | itoman
# Processing Record 38 of Set 12 | deming
# Processing Record 39 of Set 12 | puerto quijarro
# babanusah not found
# Processing Record 40 of Set 12 | babanusah
# Processing Record 41 of Set 12 | itarema
# Processing Record 42 of Set 12 | palora
# Processing Record 43 of Set 12 | xinyu
# Processing Record 44 of Set 12 | moyale
# Processing Record 45 of Set 12 | luwuk
# Processing Record 46 of Set 12 | maumere
# Processing Record 47 of Set 12 | phek
# Processing Record 48 of Set 12 | marsa matruh
# Processing Record 49 of Set 12 | kalmunai
# Processing Record 50 of Set 12 | zaysan
# Processing Record 1 of Set 13 | wakkanai
# Processing Record 2 of Set 13 | lamu
# Processing Record 3 of Set 13 | sechura
# Processing Record 4 of Set 13 | agogo
# Processing Record 5 of Set 13 | vostok
# Processing Record 6 of Set 13 | maniitsoq
# Processing Record 7 of Set 13 | severo-kurilsk
# Processing Record 8 of Set 13 | pevek
# Processing Record 9 of Set 13 | valdez
# one hundred mile house not found
# Processing Record 10 of Set 13 | one hundred mile house
# Processing Record 11 of Set 13 | melito di porto salvo
# Processing Record 12 of Set 13 | dalnerechensk
# wulanhaote not found
# Processing Record 13 of Set 13 | wulanhaote
# Processing Record 14 of Set 13 | whitehorse
# yialos not found
# Processing Record 15 of Set 13 | yialos
# Processing Record 16 of Set 13 | ekhabi
# Processing Record 17 of Set 13 | chongwe
# Processing Record 18 of Set 13 | santa cruz
# Processing Record 19 of Set 13 | bhainsdehi
# Processing Record 20 of Set 13 | bermejillo
# Processing Record 21 of Set 13 | provost
# Processing Record 22 of Set 13 | laguna
# Processing Record 23 of Set 13 | beloha
# Processing Record 24 of Set 13 | padang
# Processing Record 25 of Set 13 | kharp
# Processing Record 26 of Set 13 | slave lake
# Processing Record 27 of Set 13 | reading
# Processing Record 28 of Set 13 | saint albans
# Processing Record 29 of Set 13 | guerrero negro
# Processing Record 30 of Set 13 | skjervoy
# katsiveli not found
# Processing Record 31 of Set 13 | katsiveli
# Processing Record 32 of Set 13 | smithers
# Processing Record 33 of Set 13 | srivardhan
# Processing Record 34 of Set 13 | manjacaze
# Processing Record 35 of Set 13 | bilibino
# Processing Record 36 of Set 13 | kirakira
# Processing Record 37 of Set 13 | yuzhne
# Processing Record 38 of Set 13 | buraydah
# Processing Record 39 of Set 13 | natal
# Processing Record 40 of Set 13 | kisangani
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0    esmeralda      CU  2021-11-08 18:28:51  21.8525  -78.1169     81.64
# 1  east london      ZA  2021-11-08 18:28:52 -33.0153   27.9116     59.94
# 2   bredasdorp      ZA  2021-11-08 18:28:52 -34.5322   20.0403     58.32
# 3       kodiak      US  2021-11-08 18:28:52  57.7900 -152.4072     35.11
# 4     tekirdag      TR  2021-11-08 18:28:53  40.9780   27.5085     52.95
#
#    Humidity  Cloudiness  Wind Speed
# 0        55          95        9.44
# 1        94          75       11.50
# 2        67          58        5.75
# 3        69           1       13.80
# 4        69         100        4.36

# %%
# Adding data to a dataframe
weather_df=pd.DataFrame(city_data)
weather_df.head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0    esmeralda      CU  2021-11-08 18:28:51  21.8525  -78.1169     81.64
# 1  east london      ZA  2021-11-08 18:28:52 -33.0153   27.9116     59.94
# 2   bredasdorp      ZA  2021-11-08 18:28:52 -34.5322   20.0403     58.32
# 3       kodiak      US  2021-11-08 18:28:52  57.7900 -152.4072     35.11
# 4     tekirdag      TR  2021-11-08 18:28:53  40.9780   27.5085     52.95
#
#    Humidity  Cloudiness  Wind Speed
# 0        55          95        9.44
# 1        94          75       11.50
# 2        67          58        5.75
# 3        69           1       13.80
# 4        69         100        4.36

# %%
# Writing to a csv file
file_to_write='weather_data/cities.csv'
weather_df.to_csv(file_to_write,index_label="City_ID")

# %%
# Extract data to plot
lat=weather_df["Lat"]
max_temp=weather_df["Max Temp"]
humidity=weather_df["Humidity"]
cloudiness=weather_df["Cloudiness"]
wind_speed=weather_df["Wind Speed"]

# %%
# Importing library to get current date
import time
# Scatter plot of latitude vs max temp
plt.scatter(lat,max_temp,edgecolors="black",alpha=0.8,marker="o",linewidth=1,label="Cities")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (\N{DEGREE SIGN}F)")
plt.title ("City Latitude Vs Max Temperature " + time.strftime('%x'))
plt.grid()

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot
plt.show()

# %%
# Scatter plot of latitude vs humidity
plt.scatter(lat,humidity,edgecolors="black",alpha=0.8,marker="o",linewidth=1,label="Cities")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title ("City Latitude Vs Humidity " + time.strftime('%x'))
plt.grid()

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot
plt.show()

# %%
# Scatter plot of latitude vs cloudiness
plt.scatter(lat,cloudiness,edgecolors="black",alpha=0.8,marker="o",linewidth=1,label="Cities")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title ("City Latitude Vs Cloudiness " + time.strftime('%x'))
plt.grid()

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot
plt.show()

# %%
# Scatter plot of latitude vs wind speed
plt.scatter(lat,wind_speed,edgecolors="black",alpha=0.8,marker="o",linewidth=1,label="Cities")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title ("City Latitude Vs Wind Speed " + time.strftime('%x'))
plt.grid()

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot
plt.show()

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.

def plot_linear_regression(x_value,y_value,y_label,title,text_position):
    # Import linear regression module from Scipy
    from scipy.stats import linregress
    # Perform linear regression
    (slope,intercept,r_value,p_value,std_err)=linregress(x_value,y_value)
    # Line equation
    line_eq="y="+str(round(slope,2))+"x+"+str(round(intercept,2))
    # Regression plot values
    regress_values=slope*x_value +intercept
    # Scatter plot
    plt.scatter(x_value,y_value)
    # Regression line
    plt.plot(x_value,regress_values,color="r")
    # Formatting
    plt.xlabel("Latitude")
    plt.ylabel(y_label)
    plt.title(title)
    plt.annotate(line_eq,text_position,color="red",fontsize=15)
    # Show the plot
    plt.show()

# %%
# Create northern and southern hemisphere df
northern_hemi_df=weather_df.loc[weather_df["Lat"]>=0]
southern_hemi_df=weather_df.loc[weather_df["Lat"]<0]

# %%
# Regression plot for Northern Hemisphere data on Max Temp
plot_linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Max Temp"], 
                      "Maximum Temperature (\N{DEGREE SIGN}F)",
                      'Linear Regression on the Northern Hemisphere \n for Maximum Temperature',
                      (0,0))

# %%
# Regression plot for Southern Hemisphere data on Max Temp
plot_linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Max Temp"], 
                      "Maximum Temperature (\N{DEGREE SIGN}F)",
                      'Linear Regression on the southern Hemisphere \n for Maximum Temperature',
                      (-50,90))

# %%
# Regression plot for Northern Hemisphere data on Humidity
plot_linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Humidity"], 
                      "Humidity (%)",
                      'Linear Regression on the Northern Hemisphere \n for Humidity (%)',
                      (50,20))

# %%
# Regression plot for Southern Hemisphere data on Humidity
plot_linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Humidity"], 
                      "Humidity (%))",
                      'Linear Regression on the southern Hemisphere \n for Humidity (%)',
                      (-50,20))

# %%
# Regression plot for Northern Hemisphere data on Cloudiness
plot_linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Cloudiness"], 
                      "% Cloudiness",
                      'Linear Regression on the Northern Hemisphere \n for % Cloudiness',
                      (50,20))

# %%
# Regression plot for Southern Hemisphere data on Cloudiness
plot_linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Cloudiness"], 
                      "% Cloudiness",
                      'Linear Regression on the southern Hemisphere \n for % Cloudiness',
                      (-50,20))

# %%
# Regression plot for Northern Hemisphere data on Wind Speed
plot_linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Wind Speed"], 
                      "Wind Speed (mph)",
                      'Linear Regression on the Northern Hemisphere \n for Wind Speed (mph)',
                      (50,20))

# %%
# Regression plot for Southern Hemisphere data on Wind Speed
plot_linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Wind Speed"], 
                      "Wind Speed (mph)",
                      'Linear Regression on the southern Hemisphere \n for Wind Speed (mph)',
                      (-50,20))
